# %%
import os
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
os.chdir("C:/Users/aroy29/Dropbox (ASU)/Strava Analysis/Data/MAG2016/Analysis_Generated_Data/Shapefiles/Tempe shapefiles")

# %%
gdf1 = gpd.read_file("Tempe_zipcodes.shp")
gdf1.plot()

# %%
gdf1 = gdf1.to_crs(gdf2.crs)

# %%
gdf2 = gpd.read_file("Tempe_edges_zipcodes.shp")
gdf2.plot()

# %%
gdf3 = gpd.sjoin(gdf2,gdf1,how="inner",op="within")
gdf3.plot()

# %%
gdf3.to_file("Tempe_street_network.shp")
